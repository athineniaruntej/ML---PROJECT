# %%
import pandas as pd
import  numpy as np
data = {
    'A': [1, 2, 3, 4],
    'B': ['arun tej', 'ishwak ram', 'karthik', np.nan],
    'C': [10, 10, 100, 110,110]
}
df = pd.DataFrame(data)
print(df.nunique())
# Out:
# A    4
# B    3
# C    1
# dtype: int64
